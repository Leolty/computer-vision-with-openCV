# %%
import numpy as np
import matplotlib.pyplot as plt

import cv2

# %%
img = cv2.imread("/Users/tianyangliu/Documents/me/ID photo/white bg.JPG")

# %%
img.shape
# Out:
# (2438, 2438, 3)

# %%
plt.imshow(img)

# %%
# matplotlib -> R G B
# opencv     -> G B R
fix_img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
plt.imshow(fix_img)

# %%
img_gray = cv2.imread("/Users/tianyangliu/Documents/me/ID photo/white bg.JPG", cv2.IMREAD_GRAYSCALE)
plt.imshow(img_gray)
